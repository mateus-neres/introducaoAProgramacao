# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-neres/Introducao-a-Programacao/blob/main/amostragem_etapa02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROJETO DE ANÁLISE ESTATISTICA ENEM 2019**
#
# Este projeto analisa os resultados do ENEM no estado de São Paulo no ano de 2019.
#
# Os dados foram extraídos do site do INEP:
#
# http://inep.gov.br/mocrodados

# %% [markdown]
# #**2° ETAPA: AMOSTRAGENS**

# %% [markdown]
# ##Exportando bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Importando dataframe

# %%
enem_sp = pd.read_csv("/content/drive/MyDrive/curso_Udemy/curso_estatistica_python/enem_2019_tratado.csv", sep = ",", encoding = "iso-8859-1")

# %% [markdown]
# ##Exibindo colunas e linhas sem abreviações
#
# para exibir as colunas e linhas de um DataFrame sem abreviações, você pode usar o método pd.set_option do Pandas para configurar as opções de exibição.

# %%
pd.set_option("display.max_columns", None)
# pd.set_option("display.max_rows", None)
# pd.set_option("display.float_format", "{:.2f}".format)

# %%
enem_sp.head()
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1   parda
# 1  1,90E+11              São Paulo     17    F             1   parda
# 2  1,90E+11  São Bernardo do Campo     19    M             1   parda
# 3  1,90E+11             Embu-Guaçu     17    F             1   parda
# 4  1,90E+11              Guarulhos     23    F             1  branca
#
#    NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 0              1                1  não_respondeu         NaN
# 1              1                2        privada 15567761.00
# 2              1                2        pública 35904958.00
# 3              1                2        pública         NaN
# 4              1                1  não_respondeu         NaN
#
#         NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 0                    NaN               1               1               1
# 1                  Belém               1               1               1
# 2  São Bernardo do Campo               1               1               1
# 3                    NaN               1               1               1
# 4                    NaN               1               1               1
#
#    TP_PRESENCA_MT  NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT    LINGUA  \
# 0               1   564.60   585.80   592.90   600.20    inglês
# 1               1   576.20   641.10   634.30   731.80    inglês
# 2               1   402.20   424.80   509.60   393.20  espanhol
# 3               1   399.60   426.80   487.20   419.20    inglês
# 4               1   625.70   646.50   629.30   796.10    inglês
#
#    TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  NOTA_REDACAO INTERNET
# 0               1.00 160.00 200.00 180.00 200.00 200.00        940.00      sim
# 1               1.00 160.00 120.00 200.00 200.00 200.00        880.00      não
# 2               1.00  80.00 160.00 120.00 100.00 100.00        560.00      sim
# 3               1.00 120.00 120.00 120.00 120.00  80.00        560.00      sim
# 4               1.00 160.00 200.00 180.00 180.00 160.00        880.00      sim

# %% [markdown]
# ##Area de amostragem será a cidade de Campinas-SP

# %%
enem_campinas = enem_sp.loc[enem_sp.MUNICIPIO_RESIDENCIA == "Campinas"]

# %%
enem_campinas.head()
# Out:
#     INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 15   1,90E+11             Campinas     17    F             1  branca
# 31   1,90E+11             Campinas     19    F             1   parda
# 51   1,90E+11             Campinas     17    F             1  branca
# 116  1,90E+11             Campinas     17    F             1  branca
# 169  1,90E+11             Campinas     17    M             1  branca
#
#      NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 15               1                1  não_respondeu         NaN
# 31               1                1  não_respondeu         NaN
# 51               1                2        pública         NaN
# 116              1                2        pública 26078562.00
# 169              1                2        privada         NaN
#
#     NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 15               NaN               1               1               1
# 31               NaN               1               1               1
# 51               NaN               1               1               1
# 116    Lagoa do Ouro               1               1               1
# 169              NaN               1               1               1
#
#      TP_PRESENCA_MT  NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT    LINGUA  \
# 15                1   422.90   496.50   509.60   496.50    inglês
# 31                1   634.20   657.40   580.90    73.10    inglês
# 51                1   420.30   485.60   517.40   417.50    inglês
# 116               1    39.70   488.10   472.50   480.50  espanhol
# 169               1   563.70   551.30   582.30   624.40    inglês
#
#      TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  NOTA_REDACAO  \
# 15                1.00 160.00 120.00 140.00 140.00 120.00        680.00
# 31                1.00 140.00 120.00 160.00 140.00 160.00        720.00
# 51                1.00 160.00 140.00 160.00 120.00 160.00        740.00
# 116               1.00 120.00  60.00  60.00 100.00   0.00        340.00
# 169               1.00 140.00 120.00 140.00 160.00 160.00        720.00
#
#     INTERNET
# 15       sim
# 31       sim
# 51       sim
# 116      sim
# 169      sim

# %%
enem_campinas.shape
# Out:
# (13198, 28)

# %% [markdown]
# ##Amostragem Aleatória Simples

# %%
np.random.seed(1)

# %%
amostra_simples = enem_campinas.sample(frac=0.20) # Porcentagem

# %%
amostra_simples.head(5)
# Out:
#        INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 439968  1,90E+11             Campinas     23    M             1  branca
# 149154  1,90E+11             Campinas     17    F             1  branca
# 70541   1,90E+11             Campinas     17    F             1  branca
# 327591  1,90E+11             Campinas     29    F             2  branca
# 479997  1,90E+11             Campinas     55    M             2  branca
#
#         NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 439968              1                1  não_respondeu         NaN
# 149154              1                2        pública 35901088.00
# 70541               1                2        privada         NaN
# 327591              1                1  não_respondeu         NaN
# 479997              1                1  não_respondeu         NaN
#
#        NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 439968              NaN               1               1               1
# 149154         Campinas               1               1               1
# 70541               NaN               1               1               1
# 327591              NaN               1               1               1
# 479997              NaN               1               1               1
#
#         TP_PRESENCA_MT  NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT    LINGUA  \
# 439968               1   388.40   456.90   491.80   535.50    inglês
# 149154               1   439.20   534.10   510.50   607.60    inglês
# 70541                1    68.00   683.10   618.20   883.90    inglês
# 327591               1   485.80   492.70   511.90   361.40  espanhol
# 479997               1   408.80   497.50   496.90   380.10  espanhol
#
#         TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  NOTA_REDACAO  \
# 439968               1.00 120.00 120.00 120.00 120.00 100.00        580.00
# 149154               1.00 100.00  80.00  80.00 100.00   0.00        360.00
# 70541                1.00 180.00 200.00 180.00 200.00 180.00        940.00
# 327591               1.00 120.00 120.00 120.00 100.00 140.00        600.00
# 479997               1.00 100.00 120.00 120.00 100.00 100.00        540.00
#
#        INTERNET
# 439968      sim
# 149154      sim
# 70541       sim
# 327591      não
# 479997      sim

# %%
amostra_simples.shape
# Out:
# (2640, 28)

# %%
amostra_simples = enem_campinas.sample(3000) # Quantidade numérica

# %%
amostra_simples.head(5)
# Out:
#        INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL     RACA  \
# 57191   1,90E+11             Campinas     17    F             1  amarela
# 215078  1,90E+11             Campinas     17    F             1    parda
# 430770  1,90E+11             Campinas     18    M             1   branca
# 409180  1,90E+11             Campinas     19    F             1    preta
# 429862  1,90E+11             Campinas     17    F             1   branca
#
#         NACIONALIDADE  TP_ST_CONCLUSAO   ESCOLA   CO_ESCOLA NO_MUNICIPIO_ESC  \
# 57191               1                2  pública 35045937.00         Campinas
# 215078              1                2  pública 35018880.00         Campinas
# 430770              1                2  privada 35112902.00         Campinas
# 409180              1                2  pública 35047120.00         Campinas
# 429862              1                2  pública 35812900.00         Campinas
#
#         TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  TP_PRESENCA_MT  \
# 57191                1               1               1               1
# 215078               1               1               1               1
# 430770               1               1               1               1
# 409180               1               1               1               1
# 429862               1               1               1               1
#
#         NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT  LINGUA  TP_STATUS_REDACAO  COMP1  \
# 57191     53.30   564.50   566.40   653.80  inglês               1.00 120.00
# 215078   481.80    49.50   513.50   507.80  inglês               1.00 120.00
# 430770   626.60   665.80   628.80   823.30  inglês               1.00 140.00
# 409180   459.70   406.10   477.70   574.70  inglês               1.00 120.00
# 429862   465.90   566.10   583.30   522.70  inglês               1.00 140.00
#
#         COMP2  COMP3  COMP4  COMP5  NOTA_REDACAO INTERNET
# 57191  120.00 120.00 140.00 120.00        620.00      sim
# 215078 120.00 120.00 120.00 100.00        580.00      sim
# 430770 180.00 120.00 160.00 160.00        760.00      sim
# 409180 120.00 120.00 120.00 140.00        620.00      sim
# 429862 120.00 120.00 160.00 100.00        640.00      sim

# %%
amostra_simples.shape
# Out:
# (3000, 28)

# %% [markdown]
# #**Referências e links úteis**
# **Referências Bibliográficas**
#
# LARSON, Ron. **Estatística Aplicada.** São Paulo: Pearson Prentice Hall, 2010.
#
# COSTA NETO, Pedro Luiz de Oliveira. **Estatística.** São Paulo: Bluncher, 2002.
#
# MORETTIN, Luiz Gonzaga. **Estatística Básica: probabilidade e inferência.** São Paulo: Pearson Prentice Hall, 2010.
#
#
#
# **LINKS ÚTEIS:**
#
# **Site INEP dos microdados do ENEM:**
#
# https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem
#
# **Estatística:**
#
# https://www.udemy.com/course/estatistica-com-linguagem-r/?referralCode=0DBFC727FE8574D5BCE8
#
# **Graus de liberdade:**
#
# https://pt.khanacademy.org/math/ap-statistics/summarizing-quantitative-data-ap/more-standard-deviation/v/another-simulation-giving-evidence-that-n-1-gives-us-an-unbiased-estimate-of-variance
#
# **Teste de Normalidade:**
#
# https://www.inf.ufsc.br/~vera.carmo/Testes_de_Hipoteses/Testes_aderencia.pdf
#
# **Bibliotecas Python**
#
# https://docs.python.org/pt-br/3/library/
#
# https://pandas.pydata.org/docs/
#
# https://docs.scipy.org/
#
# https://www.anaconda.com/products/individual
#
# **Gráficos**
#
# https://seaborn.pydata.org/index.html
#
# https://plotly.com/python/reference/#layout
